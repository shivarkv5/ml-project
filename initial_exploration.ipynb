# %% [markdown]
# # Part A

# %%
# Your code here
import pandas as pd
dataframe=pd.read_csv('FW_Veg_Rem_Combined.csv')

# %%
dataframe.keys()
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'fire_name', 'fire_size',
#        'fire_size_class', 'stat_cause_descr', 'latitude', 'longitude', 'state',
#        'disc_clean_date', 'cont_clean_date', 'discovery_month',
#        'disc_date_final', 'cont_date_final', 'putout_time', 'disc_date_pre',
#        'disc_pre_year', 'disc_pre_month', 'wstation_usaf', 'dstation_m',
#        'wstation_wban', 'wstation_byear', 'wstation_eyear', 'Vegetation',
#        'fire_mag', 'weather_file', 'Temp_pre_30', 'Temp_pre_15', 'Temp_pre_7',
#        'Temp_cont', 'Wind_pre_30', 'Wind_pre_15', 'Wind_pre_7', 'Wind_cont',
#        'Hum_pre_30', 'Hum_pre_15', 'Hum_pre_7', 'Hum_cont', 'Prec_pre_30',
#        'Prec_pre_15', 'Prec_pre_7', 'Prec_cont', 'remoteness'],
#       dtype='object')

# %%
print(dataframe.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55367 entries, 0 to 55366
# Data columns (total 43 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        55367 non-null  int64
#  1   Unnamed: 0.1      55367 non-null  int64
#  2   fire_name         25913 non-null  object
#  3   fire_size         55367 non-null  float64
#  4   fire_size_class   55367 non-null  object
#  5   stat_cause_descr  55367 non-null  object
#  6   latitude          55367 non-null  float64
#  7   longitude         55367 non-null  float64
#  8   state             55367 non-null  object
#  9   disc_clean_date   55367 non-null  object
#  10  cont_clean_date   27477 non-null  object
#  11  discovery_month   55367 non-null  object
#  12  disc_date_final   28708 non-null  object
#  13  cont_date_final   25632 non-null  object
#  14  putout_time       27477 non-null  object
#  15  disc_date_pre     55367 non-null  object
# ...

# %%
dataframe.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1 fire_name  fire_size fire_size_class  \
# 0           0             0       NaN       10.0               C
# 1           1             1       NaN        3.0               B
# 2           2             2       NaN       60.0               C
# 3           3             3    WNA  1        1.0               B
# 4           4             4       NaN        2.0               B
#
#     stat_cause_descr   latitude   longitude state disc_clean_date  ...  \
# 0  Missing/Undefined  18.105072  -66.753044    PR       2/11/2007  ...
# 1              Arson  35.038330  -87.610000    TN      12/11/2006  ...
# 2              Arson  34.947800  -88.722500    MS       2/29/2004  ...
# 3     Debris Burning  39.641400 -119.308300    NV        6/6/2005  ...
# 4      Miscellaneous  30.700600  -90.591400    LA       9/22/1999  ...
#
#   Wind_cont Hum_pre_30 Hum_pre_15  Hum_pre_7   Hum_cont Prec_pre_30  \
# 0  3.250413  78.216590  76.793750  76.381579  78.724370         0.0
# ...

# %% [markdown]
# ### 2. Did you discover interesting relations?
#
# *Yes, there seems to be many relations found in the dataset, some of them are as follows:*
# 1. *fire_size, stat_cause_descr -> fire_size_class*
#
# By using fire_size and stat_cause_descr we can classify the fire_size_class
#
# 2. *fire_mag, Vegetation -> putout_time*
#
# By using fire_mag and vegetation have we can predict the putout_time.
#
# Of course there are more factors like the hum_per_7(humidity of the area before 7 days) and Wind_pre_7(winds of the area prior to 7 days) and temperatures. But for the sake of this research, I will be considering only the fire_mag and vegetation.

# %% [markdown]
# ###  3. What feature/s would you like to be able to predict?
# * As, I mentioned before, I will be predicting putout_time and classifying fire_size_class.

# %% [markdown]
# # 4. Data Cleaning

# %%
df=dataframe.copy()
# ["fire_name","fire_size","fire_size_class","stat_cause_descr","state","disc_clean_date","cont_clean_date","discovery_month","disc_date_final","cont_date_final","putout_time","Vegetation","fire_mag"]
col_drop= ['Unnamed: 0', 'Unnamed: 0.1','latitude', 'longitude','wstation_usaf', 'wstation_wban', 'wstation_byear', 'wstation_eyear', 'Temp_pre_30', 'Temp_pre_15', 'Temp_pre_7',
        'Temp_cont', 'Wind_pre_30', 'Wind_pre_15', 'Wind_pre_7', 'Wind_cont', 'Hum_pre_30', 'Hum_pre_15', 'Hum_pre_7', 'Hum_cont', 'Prec_pre_30','Prec_pre_15', 'Prec_pre_7', 'Prec_cont', 'remoteness']
df.drop(columns=col_drop,inplace=True, axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55367 entries, 0 to 55366
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   fire_name         25913 non-null  object
#  1   fire_size         55367 non-null  float64
#  2   fire_size_class   55367 non-null  object
#  3   stat_cause_descr  55367 non-null  object
#  4   state             55367 non-null  object
#  5   disc_clean_date   55367 non-null  object
#  6   cont_clean_date   27477 non-null  object
#  7   discovery_month   55367 non-null  object
#  8   disc_date_final   28708 non-null  object
#  9   cont_date_final   25632 non-null  object
#  10  putout_time       27477 non-null  object
#  11  disc_date_pre     55367 non-null  object
#  12  disc_pre_year     55367 non-null  int64
#  13  disc_pre_month    55367 non-null  object
#  14  dstation_m        55367 non-null  float64
#  15  Vegetation        55367 non-null  int64
# ...

# %%
df.head()
# Out:
#   fire_name  fire_size fire_size_class   stat_cause_descr state  \
# 0       NaN       10.0               C  Missing/Undefined    PR
# 1       NaN        3.0               B              Arson    TN
# 2       NaN       60.0               C              Arson    MS
# 3    WNA  1        1.0               B     Debris Burning    NV
# 4       NaN        2.0               B      Miscellaneous    LA
#
#   disc_clean_date cont_clean_date discovery_month disc_date_final  \
# 0       2/11/2007             NaN             Feb             NaN
# 1      12/11/2006             NaN             Dec             NaN
# 2       2/29/2004             NaN             Feb             NaN
# 3        6/6/2005        6/6/2005             Jun   6/6/2005 2:14
# 4       9/22/1999             NaN             Sep             NaN
#
#   cont_date_final                putout_time disc_date_pre  disc_pre_year  \
# 0             NaN                        NaN     1/12/2007           2007
# ...

# %% [markdown]
# # The columns we are using are: fire_size, stat_cause_descr, fire_size_class,fire_mag, Vegetation, putout_time
# # Removing null values

# %%
import numpy as np
df.replace('', np.nan, inplace=True)
df.dropna(inplace=True)

# %%
df.head()
# Out:
#            fire_name  fire_size fire_size_class stat_cause_descr state  \
# 3             WNA  1       1.00               B   Debris Burning    NV
# 9              CRAZY       1.00               B    Miscellaneous    ND
# 26        STO3573155       2.00               B   Debris Burning    AR
# 31       AXE RONDEAU       1.20               B   Debris Burning    ND
# 35  FY2001-EARLY-021      30.18               C   Debris Burning    GA
#
#    disc_clean_date cont_clean_date discovery_month   disc_date_final  \
# 3         6/6/2005        6/6/2005             Jun     6/6/2005 2:14
# 9        4/19/2004       4/19/2004             Apr   4/19/2004 20:30
# 26       1/19/2014       1/19/2014             Jan   1/19/2014 11:58
# 31        4/7/2007        4/7/2007             Apr    4/7/2007 20:16
# 35      10/19/2000      10/19/2000             Oct  10/19/2000 20:55
#
#      cont_date_final                putout_time disc_date_pre  disc_pre_year  \
# ...

# %% [markdown]
# * I have selected specific columns for doing operations and copied the rest of the columns in a new dataframe called df
# * I have used dropna() which removes any collumns and rows with null values

# %% [markdown]
# ## Spliting into testing and training sets

# %%
import numpy as np
from sklearn.model_selection import train_test_split
training_set, testing_set = train_test_split(df, test_size=0.30, random_state=90)
print(training_set.info())
print(testing_set.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12341 entries, 38608 to 15170
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   fire_name         12341 non-null  object
#  1   fire_size         12341 non-null  float64
#  2   fire_size_class   12341 non-null  object
#  3   stat_cause_descr  12341 non-null  object
#  4   state             12341 non-null  object
#  5   disc_clean_date   12341 non-null  object
#  6   cont_clean_date   12341 non-null  object
#  7   discovery_month   12341 non-null  object
#  8   disc_date_final   12341 non-null  object
#  9   cont_date_final   12341 non-null  object
#  10  putout_time       12341 non-null  object
#  11  disc_date_pre     12341 non-null  object
#  12  disc_pre_year     12341 non-null  int64
#  13  disc_pre_month    12341 non-null  object
#  14  dstation_m        12341 non-null  float64
#  15  Vegetation        12341 non-null  int64
# ...

# %%
training_set.head()
# Out:
#                fire_name  fire_size fire_size_class   stat_cause_descr state  \
# 38608           RIDGE RD        1.0               B              Arson    TN
# 15317        1.31201E+13        3.0               B           Campfire    MS
# 40206    FISHERMAN CREEK       81.0               C          Lightning    WY
# 44777  IRONHORSE COMMAND    17000.0               G      Miscellaneous    FL
# 19109        DAVIS CREEK        5.0               B  Missing/Undefined    MO
#
#       disc_clean_date cont_clean_date discovery_month  disc_date_final  \
# 38608        5/7/2010        5/7/2010             May   5/7/2010 13:38
# 15317       1/16/2014       1/16/2014             Jan  1/16/2014 15:59
# 40206        7/5/2001      11/28/2001             Jul   7/5/2001 11:30
# 44777       2/28/2011       3/20/2011             Feb   2/28/2011 9:00
# 19109       2/25/2009       2/27/2009             Feb  2/25/2009 16:00
#
#         cont_date_final                  putout_time disc_date_pre  \
# ...

# %%
testing_set.head()
# Out:
#                     fire_name  fire_size fire_size_class stat_cause_descr  \
# 17098  MARION MANN ROAD  (12)       2.50               B   Debris Burning
# 53425                     PIT   11496.00               G        Lightning
# 31724       FY2001-BARTOW-048       2.17               B   Debris Burning
# 29283      FY2001-FORSYTH-003       1.77               B   Debris Burning
# 15986               PINE GATE      12.00               C        Powerline
#
#       state disc_clean_date cont_clean_date discovery_month  disc_date_final  \
# 17098    FL       3/16/2013       3/16/2013             Mar  3/16/2013 13:01
# 53425    CA       6/22/2008       10/6/2008             Jun  6/22/2008 10:00
# 31724    GA        2/4/2001        2/4/2001             Feb   2/4/2001 13:34
# 29283    GA        1/6/2001        1/6/2001             Jan   1/6/2001 13:45
# 15986    WA       9/26/2014      10/10/2014             Sep  9/26/2014 13:15
#
# ...
